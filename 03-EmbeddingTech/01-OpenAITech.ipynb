# %%
import os
from dotenv import load_dotenv
load_dotenv() # load all my environment variables
# Out:
# True

# %%
os.environ["OPEN_API_KEY"]=os.getenv("OPENAI_API_KEY") # Set environment variable for OpenAI API key.It is to load env variable from .env file and set it to os.environ for use in the script.

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large") # Initialize OpenAIEmbeddings with specified model.
embeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from langchain_openai import OpenAIEmbeddings
#       2 embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
#       3 embeddings
#
# ModuleNotFoundError: No module named 'langchain_openai'

# %%
text= "This is tutorial for OpenAI embeddings"
embeddings.embed_query(text) # embedding for a single text.It returns a list of floats which is the embedding vector for the input text.

# %%
len(query_result) # length of the embedding vector.It took the text and converted it into a vector of 1536 dimensions.

# %%
embedding_1024=OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024)# Initialize OpenAIEmbeddings with 1024 dimension model.
embedding_1024
query_result_1024=embedding_1024.embed_query(text) # embedding for a single text with 1024 dimensions.
len(query_result_1024) # length of the embedding vector with 1024 dimensions.
